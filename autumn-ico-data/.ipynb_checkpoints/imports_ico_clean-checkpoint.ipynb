# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
imports = "Imports.csv"
imports_df = pd.read_csv(imports)
imports_df
# Out:
#    Imports by selected importing countries Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                   In thousand 60-kg bags        NaN        NaN        NaN
# 1                                      NaN        NaN        NaN        NaN
# 2                           Calendar years       1990       1991       1992
# 3                                      NaN        NaN        NaN        NaN
# 4                           European Union     45,781     43,950     47,618
# 5                                  Austria      1,880      2,058      2,206
# 6                                  Belgium        NaN        NaN        NaN
# 7                       Belgium/Luxembourg      2,015      1,746      1,828
# 8                                 Bulgaria        268        200        182
# 9                                  Croatia        NaN        NaN        168
# 10                                  Cyprus         50         54         41
# ...

# %%
imports_df.dropna(subset=["Imports by selected importing countries"], how="all", inplace=True)
imports_df
# Out:
#    Imports by selected importing countries Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                   In thousand 60-kg bags        NaN        NaN        NaN
# 2                           Calendar years       1990       1991       1992
# 4                           European Union     45,781     43,950     47,618
# 5                                  Austria      1,880      2,058      2,206
# 6                                  Belgium        NaN        NaN        NaN
# 7                       Belgium/Luxembourg      2,015      1,746      1,828
# 8                                 Bulgaria        268        200        182
# 9                                  Croatia        NaN        NaN        168
# 10                                  Cyprus         50         54         41
# 11                          Czech Republic        659        525        475
# 12                                 Denmark        959        983      1,062
# ...

# %%
imports_df = imports_df.drop(index=[0,43])
imports_df
# Out:
#    Imports by selected importing countries Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 2                           Calendar years       1990       1991       1992
# 4                           European Union     45,781     43,950     47,618
# 5                                  Austria      1,880      2,058      2,206
# 6                                  Belgium        NaN        NaN        NaN
# 7                       Belgium/Luxembourg      2,015      1,746      1,828
# 8                                 Bulgaria        268        200        182
# 9                                  Croatia        NaN        NaN        168
# 10                                  Cyprus         50         54         41
# 11                          Czech Republic        659        525        475
# 12                                 Denmark        959        983      1,062
# 13                                 Estonia        NaN        NaN         16
# ...

# %%
imports_df.columns = imports_df.iloc[0]

# %%
imports_df.head()
# Out:
# 2         Calendar years    1990    1991    1992    1993    1994    1995  \
# 2         Calendar years    1990    1991    1992    1993    1994    1995
# 4         European Union  45,781  43,950  47,618  48,451  48,868  46,231
# 5                Austria   1,880   2,058   2,206   1,836   1,417   1,231
# 6                Belgium     NaN     NaN     NaN     NaN     NaN     NaN
# 7     Belgium/Luxembourg   2,015   1,746   1,828   2,063   2,262   2,401
#
# 2    1996    1997    1998  ...    2009    2010    2011    2012    2013  \
# 2    1996    1997    1998  ...    2009    2010    2011    2012    2013
# 4  49,312  50,795  52,011  ...  67,178  69,824  70,236  72,263  72,237
# 5   1,210   1,294   1,293  ...   1,309   1,369   1,452   1,559   1,555
# 6     NaN     NaN     NaN  ...   5,916   5,924   5,828   5,668   5,502
# 7   2,526   2,544   3,580  ...     NaN     NaN     NaN     NaN     NaN
#
# 2    2014    2015    2016    2017    2018
# 2    2014    2015    2016    2017    2018
# ...

# %%
imports_df = imports_df.drop(2)
imports_df.reset_index(drop=True)
imports_df.head()
# Out:
# 2         Calendar years    1990    1991    1992    1993    1994    1995  \
# 4         European Union  45,781  43,950  47,618  48,451  48,868  46,231
# 5                Austria   1,880   2,058   2,206   1,836   1,417   1,231
# 6                Belgium     NaN     NaN     NaN     NaN     NaN     NaN
# 7     Belgium/Luxembourg   2,015   1,746   1,828   2,063   2,262   2,401
# 8               Bulgaria     268     200     182     397     463     515
#
# 2    1996    1997    1998  ...    2009    2010    2011    2012    2013  \
# 4  49,312  50,795  52,011  ...  67,178  69,824  70,236  72,263  72,237
# 5   1,210   1,294   1,293  ...   1,309   1,369   1,452   1,559   1,555
# 6     NaN     NaN     NaN  ...   5,916   5,924   5,828   5,668   5,502
# 7   2,526   2,544   3,580  ...     NaN     NaN     NaN     NaN     NaN
# 8     272     294     342  ...     523     528     482     560     609
#
# 2    2014    2015    2016    2017    2018
# 4  76,212  76,897  81,455  79,211  83,869
# ...

# %%
imports_df = imports_df.rename(columns = {"Calendar years": "Country"})
imports_df.head()
# Out:
# 2                Country    1990    1991    1992    1993    1994    1995  \
# 4         European Union  45,781  43,950  47,618  48,451  48,868  46,231
# 5                Austria   1,880   2,058   2,206   1,836   1,417   1,231
# 6                Belgium     NaN     NaN     NaN     NaN     NaN     NaN
# 7     Belgium/Luxembourg   2,015   1,746   1,828   2,063   2,262   2,401
# 8               Bulgaria     268     200     182     397     463     515
#
# 2    1996    1997    1998  ...    2009    2010    2011    2012    2013  \
# 4  49,312  50,795  52,011  ...  67,178  69,824  70,236  72,263  72,237
# 5   1,210   1,294   1,293  ...   1,309   1,369   1,452   1,559   1,555
# 6     NaN     NaN     NaN  ...   5,916   5,924   5,828   5,668   5,502
# 7   2,526   2,544   3,580  ...     NaN     NaN     NaN     NaN     NaN
# 8     272     294     342  ...     523     528     482     560     609
#
# 2    2014    2015    2016    2017    2018
# 4  76,212  76,897  81,455  79,211  83,869
# ...

# %%
final_df = imports_df.set_index(keys="Country")
final_df.head()
# Out:
# 2                        1990    1991    1992    1993    1994    1995    1996  \
# Country
# European Union         45,781  43,950  47,618  48,451  48,868  46,231  49,312
#    Austria              1,880   2,058   2,206   1,836   1,417   1,231   1,210
#    Belgium                NaN     NaN     NaN     NaN     NaN     NaN     NaN
#    Belgium/Luxembourg   2,015   1,746   1,828   2,063   2,262   2,401   2,526
#    Bulgaria               268     200     182     397     463     515     272
#
# 2                        1997    1998    1999  ...    2009    2010    2011  \
# Country                                        ...
# European Union         50,795  52,011  52,655  ...  67,178  69,824  70,236
#    Austria              1,294   1,293   1,500  ...   1,309   1,369   1,452
#    Belgium                NaN     NaN   3,003  ...   5,916   5,924   5,828
#    Belgium/Luxembourg   2,544   3,580     NaN  ...     NaN     NaN     NaN
# ...

# %%
final_df.to_csv("imports_ico.csv", header=True)
