# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
inventories = "Inventories.csv"
inventories_df = pd.read_csv(inventories)
inventories_df
# Out:
#    Inventories of green coffee in selected importing countries Unnamed: 1  \
# 0                              In thousand 60-kg bags                 NaN
# 1                                                 NaN                 NaN
# 2                              At the end of December                1990
# 3                                                 NaN                 NaN
# 4                         Inventories of Green Coffee              15,619
# 5                                                 NaN                 NaN
# 6                                      European Union               7,692
# 7                                             Austria                 333
# 8                                              Cyprus                  10
# 9                                             Denmark                  89
# 10                                            Finland                 176
# 11                                             France                 573
# ...

# %%
inventories_df.dropna(subset=["Inventories of green coffee in selected importing countries"], how="all", inplace=True)
inventories_df
# Out:
#    Inventories of green coffee in selected importing countries Unnamed: 1  \
# 0                              In thousand 60-kg bags                 NaN
# 2                              At the end of December                1990
# 4                         Inventories of Green Coffee              15,619
# 6                                      European Union               7,692
# 7                                             Austria                 333
# 8                                              Cyprus                  10
# 9                                             Denmark                  89
# 10                                            Finland                 176
# 11                                             France                 573
# 12                                            Germany               4,000
# 13                                            Ireland                 NaN
# 14                                              Italy                 215
# ...

# %%
inventories_df = inventories_df.drop(index=[0, 4, 6, 26, 28, 29])
inventories_df
# Out:
#    Inventories of green coffee in selected importing countries Unnamed: 1  \
# 2                              At the end of December                1990
# 7                                             Austria                 333
# 8                                              Cyprus                  10
# 9                                             Denmark                  89
# 10                                            Finland                 176
# 11                                             France                 573
# 12                                            Germany               4,000
# 13                                            Ireland                 NaN
# 14                                              Italy                 215
# 15                                        Netherlands               1,752
# 16                                           Portugal                  68
# 17                                              Spain                 200
# ...

# %%
inventories_df["Inventories of green coffee in selected importing countries"] = inventories_df["Inventories of green coffee in selected importing countries"].replace({"USA": "United States"})
inventories_df
# Out:
#    Inventories of green coffee in selected importing countries Unnamed: 1  \
# 2                              At the end of December                1990
# 7                                             Austria                 333
# 8                                              Cyprus                  10
# 9                                             Denmark                  89
# 10                                            Finland                 176
# 11                                             France                 573
# 12                                            Germany               4,000
# 13                                            Ireland                 NaN
# 14                                              Italy                 215
# 15                                        Netherlands               1,752
# 16                                           Portugal                  68
# 17                                              Spain                 200
# ...

# %%
inventories_df.columns = inventories_df.iloc[0]

# %%
inventories_df.head()
# Out:
# 2   At the end of December  1990  1991  1992  1993  1994  1995  1996  1997  \
# 2   At the end of December  1990  1991  1992  1993  1994  1995  1996  1997
# 7                  Austria   333   333   367   333   283   274   246   231
# 8                   Cyprus    10    12    10     8    13    13    12     6
# 9                  Denmark    89    89    89    89    89    89    89    89
# 10                 Finland   176   223   213   188   282   220   140   181
#
# 2   1998  ...  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 2   1998  ...  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 7    210  ...   138   141   111    97    92    96    96    90    80    80
# 8      9  ...     5     5     6     4     7    12     6     2     3     5
# 9     89  ...    89    89    89    89    89    89    89    89    89    89
# 10   162  ...    83    83    83    83    83    83    83    83    83    83
#
# [5 rows x 30 columns]

# %%
inventories_df = inventories_df.drop(2)
inventories_df.reset_index(drop=True)
inventories_df.head()
# Out:
# 2  At the end of December 1990 1991 1992 1993 1994 1995 1996 1997 1998  ...  \
# 7                 Austria  333  333  367  333  283  274  246  231  210  ...
# 8                  Cyprus   10   12   10    8   13   13   12    6    9  ...
# 9                 Denmark   89   89   89   89   89   89   89   89   89  ...
# 10                Finland  176  223  213  188  282  220  140  181  162  ...
# 11                 France  573  562  537  389  481  301  266  317  350  ...
#
# 2  2009 2010 2011 2012 2013 2014 2015 2016 2017 2018
# 7   138  141  111   97   92   96   96   90   80   80
# 8     5    5    6    4    7   12    6    2    3    5
# 9    89   89   89   89   89   89   89   89   89   89
# 10   83   83   83   83   83   83   83   83   83   83
# 11  483  427  414  446  438  499  507  572  475  464
#
# [5 rows x 30 columns]

# %%
inventories_df = inventories_df.rename(columns = {"At the end of December": "Country"})
inventories_df.head()
# Out:
# 2      Country 1990 1991 1992 1993 1994 1995 1996 1997 1998  ... 2009 2010  \
# 7      Austria  333  333  367  333  283  274  246  231  210  ...  138  141
# 8       Cyprus   10   12   10    8   13   13   12    6    9  ...    5    5
# 9      Denmark   89   89   89   89   89   89   89   89   89  ...   89   89
# 10     Finland  176  223  213  188  282  220  140  181  162  ...   83   83
# 11      France  573  562  537  389  481  301  266  317  350  ...  483  427
#
# 2  2011 2012 2013 2014 2015 2016 2017 2018
# 7   111   97   92   96   96   90   80   80
# 8     6    4    7   12    6    2    3    5
# 9    89   89   89   89   89   89   89   89
# 10   83   83   83   83   83   83   83   83
# 11  414  446  438  499  507  572  475  464
#
# [5 rows x 30 columns]

# %%
# final_df = inventories_df.set_index(keys="Country")
# final_df.head()

# %%
final_df.to_csv("inventories_ico.csv", header=True)
