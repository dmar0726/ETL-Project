# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Convert CSVs into Pandas DataFrames

# %%
import_consumption = "Disappearance.csv"
import_consumption_df = pd.read_csv(import_consumption)
renamed_df = import_consumption_df.rename(columns = {"Disappearance (consumption) in selected importing countries": "Disappearance"})
renamed_df
# Out:
#                           Disappearance Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                In thousand 60-kg bags        NaN        NaN        NaN
# 1                                   NaN        NaN        NaN        NaN
# 2                        Calendar years       1990       1991       1992
# 3                                   NaN        NaN        NaN        NaN
# 4                        European Union     34,230     37,663     38,240
# 5                               Austria      1,340      1,302      1,212
# 6                               Belgium        NaN        NaN        NaN
# 7                    Belgium/Luxembourg      1,124        708        696
# 8                              Bulgaria        102         17        175
# 9                               Croatia        NaN        NaN        135
# 10                               Cyprus         31         45         39
# 11                       Czech Republic        659        525        472
# ...

# %%
# df = df[df['EPS'].notna()]
# df.dropna(how='all') 
# df = df[pd.notnull(df['EPS'])]
# df.dropna(subset=['EPS'], how='all', inplace=True)

renamed_df.dropna(subset=["Disappearance"], how="all", inplace=True)
renamed_df
# Out:
#                           Disappearance Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                In thousand 60-kg bags        NaN        NaN        NaN
# 2                        Calendar years       1990       1991       1992
# 4                        European Union     34,230     37,663     38,240
# 5                               Austria      1,340      1,302      1,212
# 6                               Belgium        NaN        NaN        NaN
# 7                    Belgium/Luxembourg      1,124        708        696
# 8                              Bulgaria        102         17        175
# 9                               Croatia        NaN        NaN        135
# 10                               Cyprus         31         45         39
# 11                       Czech Republic        659        525        472
# 12                              Denmark        865        909        959
# 13                              Estonia        NaN        NaN         13
# ...

# %%
# renamed_df.delete(renamed_df.loc[renamed_df["Disappearance"] == "In thousand 60-kg bags"])
dropped_df = renamed_df.drop(index=[0,43])

# %%
dropped_df.head()
# Out:
#            Disappearance Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2         Calendar years       1990       1991       1992       1993
# 4         European Union     34,230     37,663     38,240     40,292
# 5                Austria      1,340      1,302      1,212      1,335
# 6                Belgium        NaN        NaN        NaN        NaN
# 7     Belgium/Luxembourg      1,124        708        696        789
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 20  \
# 2       1994       1995       1996       1997       1998  ...        2009
# 4     36,850     38,735     40,041     39,352     39,964  ...      40,042
# 5      1,086      1,012      1,076      1,087      1,105  ...         886
# 6        NaN        NaN        NaN        NaN        NaN  ...         934
# 7        958      1,073      1,039        886      1,309  ...         NaN
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# ...

# %%
dropped_df.columns = dropped_df.iloc[0]
print(dropped_df)

# dropped_df.columns = dropped_df[header_row]
# Out:
# 4          European Union  34,230  37,663  38,240  40,292  36,850  38,735  \
# 4          European Union  34,230  37,663  38,240  40,292  36,850  38,735
# 5                 Austria   1,340   1,302   1,212   1,335   1,086   1,012
# 6                 Belgium     NaN     NaN     NaN     NaN     NaN     NaN
# 7      Belgium/Luxembourg   1,124     708     696     789     958   1,073
# 8                Bulgaria     102      17     175     327     353     393
# 9                 Croatia     NaN     NaN     135     132     164     288
# 10                 Cyprus      31      45      39      78      45      43
# 11         Czech Republic     659     525     472     448     509     511
# 12                Denmark     865     909     959     891     908     758
# 13                Estonia     NaN     NaN      13      44      63      83
# 14                Finland   1,070     966   1,030   1,129   1,050     735
# 15                 France   5,205   5,557   5,614   5,507   5,111   5,313
# ...

# %%
dropped_df = dropped_df.drop(2)
dropped_df
# Out:
# 2          Calendar years    1990    1991    1992    1993    1994    1995  \
# 4          European Union  34,230  37,663  38,240  40,292  36,850  38,735
# 5                 Austria   1,340   1,302   1,212   1,335   1,086   1,012
# 6                 Belgium     NaN     NaN     NaN     NaN     NaN     NaN
# 7      Belgium/Luxembourg   1,124     708     696     789     958   1,073
# 8                Bulgaria     102      17     175     327     353     393
# 9                 Croatia     NaN     NaN     135     132     164     288
# 10                 Cyprus      31      45      39      78      45      43
# 11         Czech Republic     659     525     472     448     509     511
# 12                Denmark     865     909     959     891     908     758
# 13                Estonia     NaN     NaN      13      44      63      83
# 14                Finland   1,070     966   1,030   1,129   1,050     735
# 15                 France   5,205   5,557   5,614   5,507   5,111   5,313
# ...
